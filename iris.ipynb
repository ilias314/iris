# %% [markdown]
# # 🌸 Iris Flower Classification — Machine Learning with Scikit-Learn
#
# This project demonstrates a full Machine Learning workflow using the popular **Iris dataset**.
# It covers data loading, exploratory data analysis (EDA), model training using multiple algorithms, model comparison, and final evaluation.
#
# ---
#
# ## Project Overview
#
# The goal of this project is to classify iris flowers into one of three species:
#
# - **Iris-setosa**
# - **Iris-versicolor**
# - **Iris-virginica**
#
# The dataset contains **150 samples**, each with **4 features**:
#
# | Feature | Description |
# |--------|-------------|
# | sepal-length | Length of the sepal (cm) |
# | sepal-width  | Width of the sepal (cm)  |
# | petal-length | Length of the petal (cm) |
# | petal-width  | Width of the petal (cm)  |
#
# The script performs the following:
#
# ✔ View dataset shape, first rows, and statistical summary
# ✔ Class distribution
# ✔ Visualizations:
# - Box plots
# - Histograms
# - Scatter plot matrix
#
# ---
#
# ## libraries Used
#
# | Library | Purpose |
# |--------|-----------|
# | Pandas | Data loading & manipulation |
# | Matplotlib | Data visualization |
# | Scikit-Learn | ML models, evaluation, train/test split |
#
# ---
#
# ## Machine Learning Models Tested
#
# The following algorithms were compared using **10-fold cross-validation**:
#
# | Model | Abbreviation |
# |--------|----------------|
# | Logistic Regression | LR |
# | Linear Discriminant Analysis | LDA |
# | K-Nearest Neighbors | KNN |
# | Decision Tree Classifier | CART |
# | Naive Bayes | NB |
# | Support Vector Machine | SVM |
#
# ### Cross-Validation Results (Accuracy)
#
# output :
# LR: 0.94
# LDA: 0.97
# KNN: 0.96
# CART: 0.95
# NB: 0.95
# SVM: 0.98
#
#
#  **SVM performed the best**, so it was chosen as the final model.
#
# ---
#
# ## Final Model Evaluation
#
# After selecting **SVM**, predictions were made on the validation dataset.
#
# Final Results:
#
# - **Accuracy:** ~96–98%
# - **Confusion Matrix**
# - **Classification Report (Precision, Recall, F1-score)**
#
# Example:
# Accuracy: 0.97
# precision recall f1-score support
# Setosa 1.00 1.00 1.00 11
# Versicolor 1.00 0.92 0.96 13
# Virginica 0.86 1.00 0.92 6
